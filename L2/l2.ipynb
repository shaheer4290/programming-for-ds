# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sympy as sp
from scipy import stats, constants, optimize
from scipy.sparse import csr_matrix

# random seed for reproducibility
np.random.seed(42)
df = pd.read_csv('../data/online food delivery dataset.csv',index_col=0)
df.head()
pd.set_option("display.float_format", lambda value: f"{value:.3f}")
# df.describe()

# %%
# For each column, print the rows, columns, and column names
print(df.shape)
print("Rows", df.shape[0])
print("Columns", df.shape[1])
print("Columns names", df.columns)

# %%
# For each column, print the data type
df.dtypes

# %%
# print the summary of the DataFrame, including the number of non-null entries and data types
df.info()

# %%
# print the descriptive statistics for all columns, using transpose to make it easier to read
df.describe(include='all').T

# %%
# To get the summary statistics for all columns, including mean, standard deviation, minimum, maximum, and quartiles, you can use the following code:
sum = df.describe().T
sum[['mean', 'std', 'min', '25%', '50%', '75%', 'max']]

# %%
# Check for null values in the DataFrame and print the count of null values for each column
df.isnull().sum()

# total missing values in the DataFrame
df.isnull().sum().sum()
# Out:
# Gender                        0
# Marital Status                0
# Occupation                    0
# Monthly Income                0
# Educational Qualifications    0
# Family size                   0
# Customer Type                 0
# latitude                      0
# longitude                     0
# Pin code                      0
# Output                        0
# Feedback                      0
# Unnamed: 13                   0
# dtype: int64
