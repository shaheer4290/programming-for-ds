# %%
# import libraries
import pandas as pd

# %%
# import libraries
import pandas as pd
df = pd.read_csv('../data/online food delivery dataset.csv', index_col=1)
print(df.head())
df.describe()
# Out:
#         Age Marital Status Occupation  Monthly Income  \
# Gender
# Female   20         Single    Student       No Income
# Female   24         Single    Student  Below Rs.10000
# Male     22         Single    Student  Below Rs.10000
# Female   22         Single    Student       No Income
# Male     22         Single    Student  Below Rs.10000
#
#        Educational Qualifications  Family size Customer Type  latitude  \
# Gender
# Female              Post Graduate            4      Frequent   12.9766
# Female                   Graduate            3       Regular   12.9770
# Male                Post Graduate            3       Regular   12.9551
# Female                   Graduate            6      Frequent   12.9473
# Male                Post Graduate            4      Frequent   12.9850
#
#         longitude  Pin code Output   Feedback Unnamed: 13
# Gender
# Female    77.5993    560001    Yes   Positive         Yes
# Female    77.5773    560009    Yes   Positive         Yes
# ...
